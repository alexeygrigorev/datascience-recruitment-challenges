# %% [markdown]
# In this solution I use cosine similarity in the TF-IDF space to select the best matching dialogue for a phrase removed from this dialogue. The performance is ~6%
#
# Running it:
#
# - `python train_vectorizer.py`
# - `python match_dialogs.py challenge_data/test_dialogs.txt challenge_data/test_missing.txt`
#
# Answers:
#
# - I chose TF-IDF because it's simple to implement and often gives good performance. It often serves as a good baseline afterwards
# - For evaluating the performance I split the trianing set such that it resembles the test set. Training set is 2 times larger than test, so I split it into two parts and evaluated the method on each. I chose to use accuracy, but probably it may make more sense to use something like MAP@3 or MAP@5
# - Weaknesses: this representation (and also the cleaning pipeline) loses a lot of information which otherwise could be useful.
#
# Other things I tried (see the other `notcleaned` notebook):
#
# - similarity in the LSI space
# - for each missing phrase select top20 candidates with TF-IDF and then train a model for selecting the best one from them. It only marginally improved over the TF-IDF baseline
#
# There are a lot of other things one can try using here, we can discuss them during the interview

# %%
from collections import defaultdict
from tqdm import tqdm
import pandas as pd
import numpy as np
import re

from nltk.tokenize import word_tokenize
from nltk.corpus import stopwords

from sklearn.feature_extraction.text import TfidfVectorizer

import cPickle

# %%
en_stopwords = set(stopwords.words('english')) | {"n't", 's', 're', 've', 'm', 'would', 'could'}

def remove_html(text):
    return re.sub('<.+?>', ' ', text)

def tokenize(phrase):
    phrase = remove_html(phrase)
    tokens = word_tokenize(phrase)
    tokens = [t.strip("'.\"?:;") for t in tokens]
    tokens = [t for t in tokens if t and t[0].isalpha() and t not in en_stopwords]
    return ' '.join(tokens)

# %%
dialogs_all = defaultdict(list)
train = set()
test = set()

with open('./challenge_data/train_dialogs.txt', 'r') as f:
    for line in tqdm(f):
        did, phrase = line.lower().strip().split(' +++$+++ ')
        phrase = tokenize(phrase)
        train.add(did)
        dialogs_all[did].append(phrase)

with open('./challenge_data/test_dialogs.txt', 'r') as f:
    for line in tqdm(f):
        did, phrase = line.lower().strip().split(' +++$+++ ')
        phrase = tokenize(phrase)
        test.add(did)
        dialogs_all[did].append(phrase)

# %%
missing_phrases = {}
test_ids = []
missing_phrases_test_orig = []

with open('./challenge_data/train_missing.txt', 'r') as f:
    for line in tqdm(f):
        did, phrase = line.lower().strip().split(' +++$+++ ')
        phrase = tokenize(phrase)
        missing_phrases[did] = phrase

with open('./challenge_data/test_missing.txt', 'r') as f:
    for i, line in enumerate(tqdm(f)):
        _, phrase = line.lower().strip().split(' +++$+++ ')
        missing_phrases_test_orig.append(phrase)
        phrase = tokenize(phrase)
        id = 't%05d' % i
        missing_phrases[id] = phrase
        test_ids.append(id)

# %%
all_texts = []
for sentences in dialogs_all.values():
    all_texts.append(' '.join(sentences))
all_texts.extend(missing_phrases.values())

# %%
vect = TfidfVectorizer(ngram_range=(1, 3), min_df=4)
vect.fit(all_texts)
# Out:
# TfidfVectorizer(analyzer=u'word', binary=False, decode_error=u'strict',
#         dtype=<type 'numpy.int64'>, encoding=u'utf-8', input=u'content',
#         lowercase=True, max_df=1.0, max_features=None, min_df=4,
#         ngram_range=(1, 3), norm=u'l2', preprocessor=None, smooth_idf=True,
#         stop_words=None, strip_accents=None, sublinear_tf=False,
#         token_pattern=u'(?u)\\b\\w\\w+\\b', tokenizer=None, use_idf=True,
#         vocabulary=None)

# %%
with open('tfidf.bin', 'wb') as f:
    cPickle.dump(vect, f)

# %%
df_train_dialogs = []

for c in train:
    doc = ' '.join(dialogs_all[c])
    mis = missing_phrases[c]
    df_train_dialogs.append((c, doc, mis))

df_train_dialogs = pd.DataFrame(df_train_dialogs)
df_train_dialogs.columns = ["cid", "dialogue", "missing"]
df_train_dialogs.head()
# Out:
#       cid                                           dialogue  \
# 0  c10424  come guys life short tell playing chicken mean...
# 1  c15145  jenny says know cook whatever honey send kentu...
# 2  c15146   guns robbers bank got guns yeah lot guns oh yeah
# 3  c10427  galvin look many years ago give shit lawyer ca...
# 4  c15140  whatsa deal jet comin let em ground got ta kil...
#
#                                              missing
# 0  seems fella trying come back d take settlement...
# 1                             looks like whole roast
# 2                           well stay away get close
# 3  damn right done going ask mistrial going reque...
# 4                                      let em ground

# %%
X_mis = vect.transform(df_train_dialogs.missing).astype('float32')
X_doc = vect.transform(df_train_dialogs.dialogue).astype('float32')

dot = (X_mis * X_doc.T).toarray()
most_similar = (-dot).argsort(axis=1)[:, 0]

# %%
truth = np.arange(len(df_train_dialogs))
np.mean(most_similar == truth)
# Out:
# 0.045298958560920546

# %%
len(train), len(test), len(train) / 2
# Out:
# (13731, 6865, 6865)

# %%
np.random.seed(1)
df_train_dialogs['fold'] = np.random.choice([0, 1], size=len(train))

# %%
for f in [0, 1]:
    fold = df_train_dialogs[df_train_dialogs.fold == f]
    X_mis = vect.transform(fold.missing).astype('float32')
    X_doc = vect.transform(fold.dialogue).astype('float32')

    dot = (X_mis * X_doc.T).toarray()
    most_similar = (-dot).argsort(axis=1)[:, 0]
    truth = np.arange(len(fold))
    print np.mean(most_similar == truth)
# Out:
# 0.0629840713138
# 0.0667828106852

# %%
df_test_dialogs = []

for c in test:
    doc = ' '.join(dialogs_all[c])
    df_test_dialogs.append((c, doc))

df_test_dialogs = pd.DataFrame(df_test_dialogs)
df_test_dialogs.columns = ["cid", "dialogue"]
df_test_dialogs.head()
# Out:
#       cid                                           dialogue
# 0  c15144  sonny gettin real bad vibes jackie talking lat...
# 1  c18238            unemployed alfie boss dead plan ooh-kay
# 2  c10421                                kathy price yes yes
# 3  c15142  hey sonny watchin tv kids know sent neighbors ...
# 4  c18231  quite see work done found real treasure terri ...

# %%
test_phrases = [missing_phrases[i] for i in test_ids]

# %%
X_mis = vect.transform(test_phrases).astype('float32')
X_doc = vect.transform(df_test_dialogs.dialogue).astype('float32')

dot = (X_mis * X_doc.T).toarray()
most_similar = (-dot).argsort(axis=1)[:, 0]

# %%
predictions = list(df_test_dialogs.cid.iloc[most_similar])

# %%
zip(predictions, missing_phrases_test_orig)
# Out:
# [('c15144', 'why?'),
#  ('c21564', 'you be careful.'),
#  ('c04275',
#   "there'll be spoils aplenty if you guide us there.  once we breach the walls, help yourself to all you can carry."),
#  ('c00468', 'everything is lovely, ted, but much too expensive.'),
#  ('c14836',
#   'i know, i know! but what more can you expect of me?! i have pared this story down to the marrow to save money but to cut more would be to--!'),
#  ('c06603', "i mean, you can play.  you're okay."),
#  ('c12273', 'yes.'),
#  ('c17029', 'come on, what were you going to say?'),
#  ('c05089',
#   'well, where i come from it kind of goes with the territory.  texas.'),
#  ('c23266',
#   'but even here we were supposed to find who knows what... and all we bring back with us is a crate of cigarettes.'),
#  ('c23001', "well, there's some flaws in her..."),
#  ('c22968', 'neither do i.'),
#  ('c15144', 'why?'),
#  ('c23983', 'doug, the traffic light...'),
#  ('c10332', 'the phone company was broken up.'),
#  ('c27433', 'you sound funny. did you do cocaine?'),
#  ('c01065',
#   "look mrs spitz... i don't know to whom i'm indebted for the recommendation but... i'm not in the business of making oaths of allegiance or giving myself character references. what i do is listen to what the people who care to call me have to say and judge whether or not i can be of help. i hope you can appreciate that, mrs spitz."),
#  ('c08041', 'who told you my name?'),
#  ('c00291', 'your guess is as good as mine.'),
#  ('c02331', "no. no. let's go upstairs."),
#  ('c02869',
#   "lucky for you.  well, there you go, guys. don't spend it all in one place. oh ... you want to count it, jack?"),
#  ('c19193',
#   'okay, now what about your sidekick punching my favorite detective? what the hell is going on?  you got no discipline in your operation.'),
#  ('c12273', 'yes?'),
#  ('c15144', 'charisma?'),
#  ('c20635', "what do you mean you're hemorrhaging?"),
#  ('c10665', "you don't feel cold?"),
#  ('c15144', 'no.'),
#  ('c23497', 'i lost my job...'),
#  ('c18697',
#   "thank christ!  we lost you!  listen, there's been a new development --"),
#  ('c04167', 'oh. sorry.'),
#  ('c08971', 'full power, sir.'),
#  ('c18405',
#   'no. the other one. the one who disappeared up the block from christie. the one they made a beef on.'),
#  ('c15144', "what's that?"),
#  ('c10665', 'you mean the rabbit?  they got him cold.'),
#  ('c13784', 'i can only speculate as to the reasons why.'),
#  ('c01324',
#   "be patient, my lord... you've seen how it is.  this girl has a way with people... but everyday we're making progress..."),
#  ('c12921', "that's the past.  it's dead."),
#  ('c09617', 'mr. clyde, i remember everything.'),
#  ('c10024', 'murder!'),
#  ('c15144', 'how about -- ?'),
#  ('c09716', 'the most logical choice.'),
#  ('c13064',
#   "i also pvc'd you.  youngest officer promoted to sergeant. two cms.  four honor medals..."),
#  ('c15413', 'where do you want to go?'),
#  ('c15144', 'i did?'),
#  ('c09611',
#   "she's fine, really..don't you worry.. just needs some rest..she's had a very long trip."),
#  ('c22500', 'two in a row?'),
#  ('c23519', "<i>him!</i>  i'll bet he sleeps with all the lights on."),
#  ('c15725',
#   "there's a vtr setup waiting in your hotel room, that you asked for. they transferred the home movies of both families onto half-inch vhs."),
#  ('c15779', "i wasn't helping you for money."),
#  ('c12417',
#   "been on the crop. may need to get some extra hands if i don't want to work on sundays."),
#  ('c18729', 'should i be worried?'),
#  ('c08541', 'thank you.'),
#  ('c21882', 'you came all the way down here to tell me that?'),
#  ('c04803', 'oh, i hope we got them in time.'),
#  ('c23238', 'dad.'),
#  ('c13191',
#   'hahh, there is always time... all in good time...there is <b>always</b> time.  you shall have your pleasure.  <b>that</b>... i <i>decree</i>'),
#  ('c08643', "you're a killer, ozzy!"),
#  ('c04079', 'i guess part of us never really leaves high school.'),
#  ('c23925', 'what good will that do?'),
#  ('c24752',
#   'i see.  and this...computer, thinks it can win by killing the mother of its enemy, kill- ing him, in effect, before he is even conceived?  a sort of retroactive abortion?'),
#  ('c20360', 'if we ... er ...'),
#  ('c15144', 'what?'),
#  ('c03247', 'enid ate a whole pan!'),
#  ('c09444', "what's that, curly?"),
#  ('c22792', 'when did you decide you were going to do bleeker?'),
#  ('c04251', 'yeah, i hate them.'),
#  ('c23927', 'so am i going to help you with your foot?'),
#  ('c04115', "1932? that's like, that's like..."),
#  ('c14672', 'nobody cares, ronald.'),
#  ('c26844', 'right by the airport -- oh, amber...'),
#  ('c09589',
#   'we thought it might be her husband. sometimes he comes and checks up on her.  she told him i was down in florida.'),
#  ('c16522', 'well, you run on now.'),
#  ('c15144', 'where?'),
#  ('c25221', 'of course, i do.'),
#  ('c13362', "why didn't you tell me? .... why didn't you hold him?"),
#  ('c07986', 'tell him it hurt --'),
#  ('c23016', "valentine.  what's he got to say for himself?"),
#  ('c15144', 'now, now.'),
#  ('c17430', "it ain't always a blessing.  my brother here?"),
#  ('c25374', "i'm still having trouble with english."),
#  ('c03231',
#   "that's where they keep them.  you want me to bring the tooth out here?"),
#  ('c21687',
#   "would you give that script a rest? it's like a friggen umbilical cord to you."),
#  ('c24570', "doesn't it have a name?"),
#  ('c01823',
#   'please let me know when you hear from daddy, get a number or something.'),
#  ('c26869', "susie's not a virgin anymore."),
#  ('c15369', "but tor, it's a starring part! you're second billed."),
#  ('c24256', "it's for your finger."),
#  ('c15605',
#   "you know, me and stan were just talking about what a fat fucking hunk o' fat fuck you are."),
#  ('c19103', 'and your husband works for somebody else.'),
#  ('c05556', "there aren't enough arrows."),
#  ('c06192', 'why in the world would <u>she</u>--'),
#  ('c15434', "no. i can't really see it."),
#  ('c02930',
#   "they look nice, i agree . . . but lacking in criminal credibility, aren't they? i might get laughed at. how much do you want for these muskets?"),
#  ('c24463', 'just say no.'),
#  ('c05198', 'a good time! is that all you care about?!'),
#  ('c02155',
#   '--and it is in my power to confer a very signal honor upon you. in my official capacity, therefore, i--'),
#  ('c25078', "nothing's going to happen. i'll come with you."),
#  ('c01753', 'well, what do you really think, though?'),
#  ('c03020', 'you... you mean earth?'),
#  ('c23261', 'he asked me to stay.'),
#  ('c13869', "don't gimme that, you never had any scruples."),
#  ('c07056', "to get somebody from a boston hospital to say he'll testify?"),
#  ('c13480', 'alone or surrounded?'),
#  ('c13252', 'dream on, blue eye.'),
#  ('c22890', "don't know--just that she was afraid--"),
#  ('c19865',
#   'because i love them, but they drive me crazy.  you know how parents are?'),
#  ('c27263', 'shut your mouth and drive!'),
#  ('c01790',
#   "you left a print! there was kel that didn't go off! there was a partial print, they tracked it back to treadstone! they know it's you!"),
#  ('c15144', 'who are the britons?'),
#  ('c10771', 'it must be weird for you to have so many sisters?'),
#  ('c17641', 'i keep thinking about him.'),
#  ('c20670', 'er, my check, please.'),
#  ('c15144', 'no.'),
#  ('c27138', '"ray!"'),
#  ('c02469', 'see you next weekend?'),
#  ('c14338', 'there is no new ending. page 750 on is exactly the same.'),
#  ('c04640', 'wandering about.'),
#  ('c14463', "oh but diddling the therapist's daughter is a challenge?"),
#  ('c12736', "i swear on my life, i won't..."),
#  ('c23244', 'yeah.'),
#  ('c14338',
#   "you're saying... there is no separate primer in the message -- because it's on every page so the recipient can decipher it wherever he is --"),
#  ('c16784', "there's nobody left around here now."),
#  ('c11564',
#   "oh excuse me, i didn't realize you had a degree in medicine. are you a doctor? are you a doctor? answer me please, are you a doctor?"),
#  ('c27148', 'oh christ.'),
#  ('c01324',
#   "with all this technology you don't even have to show up for work.  who needs cops when you've got gizmos."),
#  ('c04381',
#   "you're right, you're a smart guy.  most counterfeiters only get ten cents on the dollar.  but this is an even swap.  pure genius."),
#  ('c15468',
#   "i ain't laid a hand on ya but to ease yo fever... remember like i say, i found you in the road..."),
#  ('c19900', 'and he is living proof.'),
#  ('c00360',
#   "oh. the green underwater ghost's...  the man with the eyes in his hands..."),
#  ('c10387', "that's right."),
#  ('c15144', 'what?'),
#  ('c19016', "how long's he staying for?"),
#  ('c16426',
#   "i'm sorry, dave, but in accordance with sub-routine c1532/4, quote, when the crew are dead or incapacitated, the computer must assume control, unquote. i must, therefore, override your authority now since you are not in any condition to intel- ligently exercise it."),
#  ('c06468',
#   "c'mon man, didn't i do you right that time i give you the turkey loaf for the ham and lima beans shit."),
#  ('c01750', 'uh, uh.  there was no such a thing as burger king.'),
#  ('c07631',
#   "...apprehensive. let's not forget these are the people who banned the mapplethorpe show. anyway, california's loaded with galleries."),
#  ('c14799', 'every guy has a type!'),
#  ('c03766', "yes, i'm your little volga boatman."),
#  ('c16958',
#   'do you really expect me to participate without knowing a single thing?'),
#  ('c07797',
#   'civilization as we know it is unraveling before our eyes.  but logan and max, with a song in their hearts are gonna march into battle to keep that from happening.'),
#  ('c19077', "sorry, daniel, i'm a physicist, not a psychiatrist."),
#  ('c09762', "oh, so now it's my fault?"),
#  ('c27394', "go  that's the way we're going to go.  what do you say?"),
#  ('c17810', "do we simply ask him where he's hidden it?"),
#  ('c04712',
#   "not that i don't enjoy a good urban legend now and then but what does any of this have to do with me?"),
#  ('c24516',
#   'he...  cares. he actually cares about these . . . . . .these people. these earth people .'),
#  ('c11118',
#   'you are to turn over the sid 6.7 program, and all its documentation, for immediate destruction. is that understood?'),
#  ('c25299', 'beautiful all over, eh?'),
#  ('c01337', 'where am i? and how can i leave?'),
#  ('c09185', "well, then appoint miller--if you're sure he'll take orders."),
#  ('c05824', 'you have his address?'),
#  ('c15246', 'new yorkers.'),
#  ('c00927',
#   'we could cross-reference a data base on media ownership. but not on our own computers. not even at home.'),
#  ('c18752', 'no. i never feel like that.'),
#  ('c26971', "i don't think so."),
#  ('c04881', 'well, i hope you enjoyed yourself.'),
#  ('c13783', 'one day you will.'),
#  ('c10813',
#   "not all experiences are good, bianca. you can't always trust the people you want to."),
#  ('c15465', "but ed, we're not even married.  and you don't have a job."),
#  ('c20439', "i don't think this is any time to be funny..."),
#  ('c17812', 'what shape is the scar?'),
#  ('c01828', 'not the hacking and gagging and spitting part.  please.'),
#  ('c06659', 'uhh... i with it sister but...'),
#  ('c11997', 'i would, if you really ever wanted to know.'),
#  ('c15144', 'no.'),
#  ('c11166', 'that was a misunderstanding.'),
#  ('c25327', 'what the fuck are you talking about.'),
#  ('c00041', "mexico. i'd like to find a quiet place to cross."),
#  ('c12273', 'yes, but--'),
#  ('c23152', 'have you tried the duck?'),
#  ('c12273', 'yes.'),
#  ('c03453', 'but you did -- i just heard it.'),
#  ('c02759',
#   "no, lil. it's just you can't understand their brand of patriotism."),
#  ('c17566', 'curtis is always more complicated than he seems. even now.'),
#  ('c23001', 'well...'),
#  ('c24833', 'david.'),
#  ('c16836', "she's just outside the door."),
#  ('c13971',
#   "i want to make you happy, toto! i'm going to tell you a story.  once upon a time a king gave a feast and there were all the most beautiful princesses of the realm. basta, one of the guards, saw the king's daughter: she was the loveliest of all! and he immediately fell in love with her. but what could a poor soldier do compared with a king's daughter?!...one day he managed to meet her and told her he couldn't live without her. the princess was so struck by the depth of his feeling that she said to the soldier  'if you will wait a hundred days and a hundred nights beneath my balcony, then in the end i'll be yours.' christ, the soldier ran off there and waited! one day, two days, ten, twenty...every night she looked out of her window, but he never budged. come rain, wind, snow, never budged! the birds shat on him and the bees ate him alive! after ninety nights he was gaunt and pale and tears streamed from his eyes but he couldn't hold them back. he didn't even have the strength to sleep any more. the princess kept watch...and on the ninety-ninth night, the soldier got up, picked up his chair and left!"),
#  ('c15144', 'i can.'),
#  ('c15144', 'what?'),
#  ('c23001', 'well, it was there.'),
#  ('c22395',
#   "we think it's ricky tan.  if you don't want to take the case, i'll understand."),
#  ('c14098', 'thirty-five bucks.'),
#  ('c23288',
#   "oh baby...i don't know anyone could pay anybody anything for work they did themselves...but if you all need to eat until your mother's well, all you have to do is say so...we have a church committee invented so nobody had to go hungry."),
#  ('c11558', "and a leader. didn't she meet castro on foreign exchange?"),
#  ('c19032', "he's not army, it's not official --"),
#  ('c08244',
#   "that girl was looking for jacqueline gibson. i'd forget it if i were you."),
#  ('c00306',
#   "i know... my girlfriends all dumped me after i put on the mask. they thought i'd lost it."),
#  ('c15578',
#   'to the pools.  now she\'s miss rock climber, and i\'m more the non-rock climber, but we\'re hiking up through the pools and there\'s a fine mist in the air, and i have the ring in my pocket, and i\'m a little nervous, i\'m lagging behind, and she says to me, get this -- "hurry up, klutz."'),
#  ('c14174', 'thank you, sir.'),
#  ('c07967',
#   "tell me where you've been.  i am going to become a startrooper and fight in the wars.  my father was a jedi!  were you in many battles?"),
#  ('c11266', "here.  this'll put hair on your chest."),
#  ('c15144', 'so?'),
#  ('c12644', "and it's just in one ear?"),
#  ('c03484', 'what novel did you read.'),
#  ('c25724', "let's go peep from the living room."),
#  ('c12273', 'yes.  cathy lee crosby stayed here.'),
#  ('c15667', 'well, they, uh they were nice enough to sew it back on.'),
#  ('c27193', "how lucky's miss universe gotta be?"),
#  ('c23261', "i didn't say i didn't love you. i said stay away from me."),
#  ('c14488', 'good god.'),
#  ('c22767',
#   "if you're going to drink it in here, i'd appreciate it if you'd not bother the customers."),
#  ('c05205', 'if what you say is true, it is a matter for the police!'),
#  ('c14098', "i'm not afraid of the fire anymore. it will purify me..."),
#  ('c12644', "now, i'm not going to wear ear- rings, i can tell you that."),
#  ('c17475', 'sort of like a new hobby, huh, general?'),
#  ('c12273', 'yes.'),
#  ('c19181', 'because you always obey orders ...'),
#  ('c17767', "they think it's your first wife..."),
#  ('c23637', "don't you teach in your school 'bout folk who ain't dead?"),
#  ('c27272', 'will you help me out...?'),
#  ('c10850',
#   "nobody really changes at summer camp. they merely find out who they are and become it more than ever.  you can't be helped, wichita. i'm not sure you can be punished, either. but let's find out..."),
#  ('c23710', "he's an artist.  anyway, he's too old to think about sex."),
#  ('c06079', 'you like me better like this.'),
#  ('c11684',
#   "yeah, and that's all i'm going to say. if you want to arrest me, go ahead..."),
#  ('c05124',
#   "and i'm not talking about hooking some poor dogfish or sand shark. i'm talking about a great white."),
#  ('c07054', '...unmarked hundreds....'),
#  ('c13347',
#   'really?  what was it like?  a down payment now, then a bonus for sleeping with me?'),
#  ('c22536', "i don't know. he just appeared as magic."),
#  ('c19494', 'every word.'),
#  ('c03326', "i'll talk to the mayor."),
#  ('c09877',
#   'i am sorry. i only felt... it seemed she was harming you. i meant...'),
#  ('c22890', "but you're not good at this.  not yet. i'm sorry."),
#  ('c10932', "i'll put this past my boss"),
#  ('c15144', 'you are <u>defending</u> what you did?'),
#  ('c24710',
#   "goebbels and goering were sure heaping honours on you. one makes you a privy councillor, the other makes you vice-president of the chamber of music, and you weren't even a member of the party, how do you explain that?"),
#  ('c12990',
#   "it'll pass. headaches are like resolutions... you forget them soon as they stop hurting."),
#  ('c15144', 'who are you?'),
#  ('c17434',
#   "i'm a lifesaver. a lighthouse. up all night in the rain, in stormy gale force wind, tornado and fucking earthquakes. i stay lit for you. i stay lit. i don't go dark. i never go dark!"),
#  ('c05104', 'how is she alright looking the way she does?'),
#  ('c02146',
#   "oh, but it does.  especially in light of the journey i'm about to make."),
#  ('c13890', 'apple core?'),
#  ('c21341', 'but how did you get here? what are you doing here?'),
#  ('c04812', 'you mean that "load" of passengers?'),
#  ('c14836',
#   "yes. and now that i've shown you that i know that much, and can guess more -- will you trust me to look for jacqueline?"),
#  ('c05920', 'how do you know you can trust me?'),
#  ('c06460', "didja tell 'em anything else?"),
#  ('c21974', 'but his leg!'),
#  ('c09402',
#   "yeah ?--how do i know?  i gotta good mind to plug you.  i shouldn't take any chances on you."),
#  ('c11261', "suzie.  then you're not her grandmother..."),
#  ('c14771', 'i think so. i was just taking a shower.'),
#  ('c00865', 'were you a drug addict?'),
#  ('c13100',
#   "hey, i invented fake i.d.s, alright. that's not the problem... they're playing disco music in there, man."),
#  ('c22890', 'should i be afraid?'),
#  ('c22526', 'who cares what he spells it? read the letter.'),
#  ('c00136',
#   'speak for yourself. i get chicks looking at me all the time. all ages.'),
#  ('c10387',
#   'all right, what about it? we get out a paper just the same. did you ever stop to think of that?'),
#  ('c06915', "the last one you'll ever see."),
#  ('c16557', 'you got me.'),
#  ('c15144', 'what happend?'),
#  ('c06415', 'i can back it up.'),
#  ('c20928', 'you got a problem with me, grady?'),
#  ('c12160',
#   'our next d.a. -- i hear bruce wayne is throwing a fundraiser.  did you get your invitation yet?'),
#  ('c16434', "i don't know, he's in a prison camp."),
#  ('c10387',
#   "i wouldn't pay jesse no mind at all. she's just a crazy old woman. hasn't been right in the head since her husband passed away.  wasn't much right before that, neither."),
#  ('c15144', 'why?'),
#  ('c19645',
#   'boat nut.  what is it about this place that makes everyone a freak for boating?'),
#  ('c23852',
#   'it would be different, if we could just give it another go around.'),
#  ('c02148',
#   "nobody is gonna die, man, will you please have the balls to follow through with a good idea?  think about it, what would you do if you were them, stay in there and choke to death, or come out?!  huh?  we're just getting them to come out for forty-five minutes, forty-five fucking minutes!  the worst that's gonna happen is they pass out, we drag 'em out here into the fresh air, and they'll be fine."),
#  ('c01337', 'i will consider it.  now leave me.'),
#  ('c01800', 'this picture--'),
#  ('c12788', "dinner.  don't be angry."),
#  ('c07877', ') you cannot kill them all.'),
#  ('c24234', 'typical male.'),
#  ('c08822', "blank faces here, o'neil."),
#  ('c15305', 'i am strong, paul, like a lion.'),
#  ('c06938', 'well, he drove it into the river.'),
#  ('c00874',
#   "yikes! no. paul wasn't into that. he followed a balanced diet and-"),
#  ('c02383', 'i feel like the night before the first day of school.'),
#  ('c06713', 'show.'),
#  ('c14021', "i'll get the girl."),
#  ('c19621', 'let me carry one of the instruments.'),
#  ('c00422', "we're alright. your ma's sleeping. you want me to get her?"),
#  ('c02824', 'no... friends from the diner maybe?'),
#  ('c16931', "money don't mean shit!"),
#  ('c11581', 'where are you headed?'),
#  ('c07178',
#   "y'know, four years ago i was working in a bakery. two years ago i was bringing marty coffee and he didn't even know my name. i run that office now. marty believed in me and i believe in him. you want me to just throw that away?"),
#  ('c06078', "i don't want to see her later.  i want to hear her <u>now</u>."),
#  ('c07152', 'a little older than paloma is now.'),
#  ('c27425', "aye?  then she's obviously not got enough to do."),
#  ('c01149', "what's that big black scar on the ground? like a fire."),
#  ('c11719', 'do you believe him?'),
#  ('c22211', "that's great earl!"),
#  ('c15144', "it's 2041..."),
#  ('c23192', 'fight what?'),
#  ('c14253', "all right- let's go into battle.  i'm redbeard."),
#  ('c20899', 'she just needs a new windshield wiper.'),
#  ('c10194', 'but why do you want me?'),
#  ('c19621', 'i need it.'),
#  ('c23009', 'you lost me.'),
#  ('c05784', "god's victim. that's her innocence. she belongs to god."),
#  ('c08056', "is there any reason why we shouldn't know the name of it?"),
#  ('c27272', 'help yourself prickfuck!'),
#  ('c13320', 'i guess i could teach you some things.'),
#  ('c04117',
#   "see, that's your problem, frank. by the time you finish figuring out stuff, i'm already finished doing it."),
#  ('c15144', 'this is he?'),
#  ('c24648',
#   "you don't know that.  if it's your belief that gives her form, then you've got to shut her out.  somehow you have to break the connection."),
#  ('c17478', 'i saw what i saw.'),
#  ('c11669', 'except for small eyes.'),
#  ('c05340',
#   'no. every time i wake up somewhere different. sometimes my bike is laying there next to me. like once when i woke up on the edge of this cliff up on carpathian ridge.'),
#  ('c12233', 'eating sushi?'),
#  ('c09598', "that's your expert opinion?"),
#  ('c14302', 'whose truth are you talking about?'),
#  ('c12047', 'shit! do not do that! where the fuck are you?'),
#  ('c00182', 'washington sent ya. i know that.'),
#  ('c05047',
#   'flashlights. luminous dials for watches. house numbers that light up.'),
#  ('c21262', 'you want some company?'),
#  ('c07797', "you're gonna be seeing a lot of me. you're sure you don't mind?"),
#  ('c23244', 'yeah.'),
#  ('c23504', "then if i wasn't born, who am i?"),
#  ('c07717', "where do you think you'll go?"),
#  ('c01553', 'did you got through my pants?'),
#  ('c19167', "i don't understand. what about you?"),
#  ('c26145', "well -- maybe. let's see what happens here."),
#  ('c27323',
#   'you\'re not "protecting" anyone.  these people\'s lives may depend on the answers you give.  these are all former associates of dr. manhattan --'),
#  ('c24547', 'you mean the one who --'),
#  ('c24995', 'the same thing.'),
#  ('c18349', 'no shit?'),
#  ('c15471', 'kind of.'),
#  ('c27452', "well, aren't you excited?"),
#  ('c15144', 'who is he?'),
#  ('c08437', 'oh, maya. no.'),
#  ('c26538', 'what does that mean?'),
#  ('c06247', "a good deal of it, i reckon. can't understand all of it."),
#  ('c13674', 'nay, bigger; women grow by men.'),
#  ('c08771', 'no, the dog.'),
#  ('c19719', "can't be any worse than this. what do you think?"),
#  ('c10980', "who's running it!"),
#  ('c25408', 'oh god, this is like a nightmare.'),
#  ('c13551', "i think she's trying that."),
#  ('c05895', 'a man whose life was empty!'),
#  ('c08068',
#   'i wonder if there might not be a very large cup of hot chocolate somewhere in the area.'),
#  ('c24323', "can you rely on how much they said you'd get?"),
#  ('c10859', 'but you know who did.'),
#  ('c16642',
#   "i'm not cynical.  can i help it that life is a disease and everyone's a victim. so you're producing exclusively for grendel records now.  hope you're taking julian for a bundle."),
#  ('c20263',
#   'we were married two years before the baby.  and then four very difficult years.'),
#  ('c15144', 'it was too noisy.'),
#  ('c16377', 'i promise, dorothy. i promise.'),
#  ('c08047', "i'm just here about my brother."),
#  ('c08541', 'thank you.'),
#  ('c10395',
#   'take your money? this guy will blow up your house and everyone in it!'),
#  ('c25413',
#   "nobody knows. there've been a lot of theories, of course. but we'll never really know for sure."),
#  ('c15144', '-- what?'),
#  ('c06384',
#   'why would you stay so long with an operation that is so clearly not a growth enterprise?'),
#  ('c18345', 'very funny, smart ass.'),
#  ('c15714', 'two of us might be more effective than one.'),
#  ('c21821',
#   "you tell me. you tell me who went to the b.i.a. -- bureau of indian annihilation and said i was messin' with your case, man. i don't give a goddamn about your case."),
#  ('c05903', 'sure. got a sixteen-year-old girl.'),
#  ('c27240',
#   "and it seems to me, a fella's trying to come back, he'd take this settlement, and get a record for himself.    i myself would take it and run like a thief."),
#  ('c13347', "la hire, i'm warning you -- don't swear!"),
#  ('c10548', "ulrich will be about.  he'll look after you."),
#  ('c26538', "that's not what i mean."),
#  ('c03711', 'when may i expect the cleaners?'),
#  ('c08787',
#   '"oh, tract housing, huh?"  laugh. "you need a new real estate agent."'),
#  ('c01361',
#   "no, that's what i want to talk to the mayor about.  we did a little job for the city a while back and we ended up getting sued, screwed and tattooed by deskworms like you."),
#  ('c23512', 'carl can wait.'),
#  ('c09372', 'six.'),
#  ('c18931', 'ever think of moving there full time?'),
#  ('c03453', 'like this.'),
#  ('c06404', "yes.  i am.  i'm sorry to antagonize you."),
#  ('c14316',
#   'dr. arroway, you are entitled to your opinion.  but we feel quite strongly that it would by both irresponsible and naive to send a human being into a completely unknown, completely uncontrollable situation absolutely defenseless.'),
#  ('c23030', 'i thought you had something planned.'),
#  ('c21341', 'you should get the order you want.'),
#  ('c08730', "then neither will you.  and i'll get to sleep at night."),
#  ('c19618',
#   "frank, but not now.  frank.  you're trying to wipe out some old business.  but not now.  i understand.  but you go call 'em back.  you call the bishop back."),
#  ('c23347', 'kit, i left that money for you days ago.'),
#  ('c18035', "a beach named x? that i'd like to see."),
#  ('c15144', 'my what?'),
#  ('c21821', 'thought you had to use some of these.'),
#  ('c08089', 'i gotta do this, stephen. i gotta know.'),
#  ('c24463', 'did she say that?'),
#  ('c15144', 'no.'),
#  ('c03718', "well, why can't you just lock the doors and go to bed?"),
#  ('c21227',
#   "he didn't.  interrogation's not in our skill set.  so c'mon, what suspicions have you master-minded off these associations?"),
#  ('c04811', "an old man's dream."),
#  ('c07356',
#   "maybe. but i'm taking no chances.  why, this kid's got a record."),
#  ('c15144', 'but i...'),
#  ('c14675',
#   "i see. i'll get together four patrols of our detectives for action tonight."),
#  ('c21415',
#   "you know what, though? i feel like i'm really ready to do it. to have sex for the first time."),
#  ('c10387', "i've got the hang of the driving.  found this place all right."),
#  ('c05708', "you're soft."),
#  ('c23803', 'please!'),
#  ('c04407', 'mm-hm.'),
#  ('c19866', "where's charlie?"),
#  ('c23616', "every time i ever see you, that's what i see."),
#  ('c10859', 'how do you know?'),
#  ('c19064',
#   'there are millions of other species on earth, doctor. only human arrogance would assume the message was meant for man.'),
#  ('c10634',
#   "i was frightened and i didn't know what to think! but you know-i believe him. i think he just wants to go home. wherever the hell that is..."),
#  ('c24347',
#   "i was with valerie, i swear. this is adrian's work. i've got to find him."),
#  ('c07738', "you're a hell of a flyer.  you can be my wingman any time."),
#  ('c10387', 'all right, then this is old stuff to you.'),
#  ('c09961', "that's a sharp jacket."),
#  ('c19956',
#   "you're not death.  you're just a kid in a jacket and a pair of pants."),
#  ('c15471', 'what kind?'),
#  ('c22166', 'what do ya want the others to get?'),
#  ('c20964', "well, i'm listening now."),
#  ('c04559', 'were you bothering by those waitresses making a fuss?'),
#  ('c02112', "that's none of your business."),
#  ('c10859', 'you know who it was?'),
#  ('c14660', 'fifth and mayflower. you know it?'),
#  ('c25648', "can't i?"),
#  ('c16380', 'i have work to do.'),
#  ('c25171', "they're not that jewish."),
#  ('c10969', 'yeah, rock particles.  dust.'),
#  ('c15144', 'finn ...'),
#  ('c15144', '"in absentia luci, tenebrae vinciunt..."'),
#  ('c01799', "if you went down on a horse... you'd tell me, right?"),
#  ('c20515', 'the presidency.  the public loves him.'),
#  ('c17283', 'why do you call it "eleanor?"'),
#  ('c10604', "wouldn't miss the semis.  how things been goin'?"),
#  ('c14746', "that's what i had in mind."),
#  ('c19718', 'francis donnelly.  pleased to meet you.'),
#  ('c25965', 'he left us!  he left us!'),
#  ('c25295', '--it\'s called "morning sickness," asshole--'),
#  ('c11430', 'go home!'),
#  ('c24420', 'you still mad at him?'),
#  ('c21434', 'fine thank you.'),
#  ('c15144', 'what?'),
#  ('c23009', 'well, i know that now.'),
#  ('c15265', 'okay, cool.'),
#  ('c03777',
#   "and not a word of them to father. he's agitated enough not hearing from victor."),
#  ('c07797',
#   "no. i should have. i told them i disagreed with you, mike and kluster that this segment is as good as the original. i'm not lying for you. i'm not gonna shut up for you. not on any of it."),
#  ('c17888', 'pure idiot.'),
#  ('c00094',
#   "good. remember, when in doubt: don't ever do what you really want to do."),
#  ('c02331', 'let me go! let me go!!'),
#  ('c01149',
#   "i'm not callin you big black africa. mommy and daddy named you julius."),
#  ('c27240',
#   "i'm afraid that anna has come back. i feel she's back, and that they're together."),
#  ('c16785', 'i never had it.'),
#  ('c20515', 'plus he fell in love with a temp.'),
#  ('c23618',
#   'i also have this odd pain in my mid section. kind of a hollow feeling...'),
#  ('c07642',
#   "this is the anniversary of the summer of love and your city fathers have declared a festival of love.  the mayor and chamber of commerce don't want tv announcing killers on the loose."),
#  ('c21077', 'sam! do me a speech, do me a line.'),
#  ('c13216',
#   "i've spent over 50 hours interviewing him.  charlie killed leno and rosemary labianca because of the ugly way the members of his family had butchered sharon tate. after seeing the blood bath on television, he wanted to show them how it should be done.  the question is, what does charlie have to do with sid 6.7?"),
#  ('c18611',
#   "there's always deaths in these waters that never turn up.  are they all shark victims?"),
#  ('c16380', 'where does he work?'),
#  ('c03368', 'and what is the magic word, mr. venkman?'),
#  ('c06874', "good god! let's get out of here! where's the elevator?"),
#  ('c22740', 'a man to see you.'),
#  ('c15144', 'no.'),
#  ('c23244', 'yeah? what do i do then?'),
#  ('c11820', "don't think it's not going to cost you."),
#  ('c18799', 'sit down... sit down... are you hungry?'),
#  ('c15144', 'why?'),
#  ('c21860',
#   "why don't we go over to the theatre and see what's really happening? after all, we've only heard from a small portion of the audience. let's hear what the majority thinks."),
#  ('c27310', 'she was murdered?'),
#  ('c21341', "how'd you get that."),
#  ('c21314',
#   'no, not yet jack. we just bought the story. saturday evening post.'),
#  ('c15144', '"it?"'),
#  ('c13631', 'you sure?'),
#  ('c16008',
#   "look -- there's a million ways to humiliate yourself - i gotta think of a new way? i mean, it's all day! every minute. id be like a monkey at the zoo. i just..."),
#  ('c08549', 'what kind of work do you think you would be qualified for?'),
#  ('c01987',
#   "showgirls. absolutely frightening. what's yours? wait, let me guess. the house on sorority row? final exam. graduation day? the dorm that dripped blood? splatter university? am i close?"),
#  ('c16399', "yes... of course... when you don't need me anymore."),
#  ('c15144', 'no.'),
#  ('c24693',
#   'you turn it on, you open it and you stand in front of it for a very long time.'),
#  ('c16924', "you! don't make me laugh."),
#  ('c13863', 'somebody told me nathan was back. how is he?'),
#  ('c08232', "you're asking for my documents?"),
#  ('c21476', 'what whispers?'),
#  ('c21821', 'do you want to hear the background of the case, first?'),
#  ('c08971', "we don't have minutes. can you give me phaser power?"),
#  ('c04394',
#   "diane, i've loved you ever since i first saw you -- right before you kicked me in the head."),
#  ('c20803', 'smells like something died.'),
#  ('c18935',
#   "barber, right? i'm freddy riedenschneider. hungry? they tell me the chow's ok here. i made some inquiries."),
#  ('c12273', 'yes.'),
#  ('c11684', 'i said go ahead.'),
#  ('c15144', "that's what it's about."),
#  ('c26686', 'smoking or non-smoking?'),
#  ('c22055', '--graduate thesis--'),
#  ('c07713', 'yeah  but i have some peculiarities also.'),
#  ('c14860', 'what -- what sort of action do you mean?'),
#  ('c14472',
#   'we have to talk.  whether to kill yourself is one of the most important decisions a teenager has to make.'),
#  ('c20236',
#   "follow him? mr. gekko i...  it's not what i do. i could lose my license. if the sec found out, i could go to jail. it's inside information, isn't it?"),
#  ('c12896',
#   'the hell you know about me?! you got no right to talk to me about that shit! the hell you think you are?'),
#  ('c01963',
#   'are you one of those people who cannot imagine the germans in their beloved paris?'),
#  ('c12273', 'yes.'),
#  ('c26538', 'what do you mean?'),
#  ('c07349', "i'm sorry i didn't get a chance to --"),
#  ('c04878', 'sure, you got one?'),
#  ('c15144', 'you off your rocker?'),
#  ('c16590', "i didn't sell it."),
#  ('c26782',
#   "well, i guess i do. for a long time i was too focused on my work, i think, but now i've really begun to think about changing myself, you know, developing, and...growing."),
#  ('c04274',
#   "that's what i'm here to talk to your brother about.  what's with him, i got to get a letter of introduction to have a 'sitdown'?"),
#  ('c08771',
#   'on the bridge. how did you know that tommy had your dog? that was no fucking hunch.'),
#  ('c12488', "ctu?  jesus.  you don't think --"),
#  ('c20005',
#   'charming guy, basil.  once after beating an army of serbians he blinded all but-'),
#  ('c18487',
#   "all right. all right. now we'll go over every step you took since you left the house."),
#  ('c14108',
#   "then talk to your brother, goddamn it. the two of you don't need any advice to get into trouble."),
#  ('c15144', 'why?'),
#  ('c18502',
#   "i really don't know. i don't live there. i was just visiting...a grave."),
#  ('c15144', 'you do?'),
#  ('c23736',
#   "i remember. you said it to her, but it was meant for me, wasn't it?"),
#  ('c15144', 'what now?'),
#  ('c15144', 'how?'),
#  ('c12497', "dude, i'm not supposed to make calls--"),
#  ('c16420',
#   "how is that possible? i mean, you try to ask him a question and suddenly it's another one of his stories.  you can't honestly say you know him."),
#  ('c20678', 'what do you mean?  it was incredibly romantic!'),
#  ('c15667',
#   'a woman should never learn to sew, and if she can she should never admit to it.  close your eyes.'),
#  ('c20188', 'pay the rent.  let the tailor wait.'),
#  ('c24825',
#   "well let's just say you're lucky you deal with children who are under anesthesia."),
#  ('c15144', 'why?'),
#  ('c08965', 'then why are you looking for her?'),
#  ('c26971', 'what did you think?'),
#  ('c25221', 'of course.'),
#  ('c20836', 'put the sense/net police on it. the matrix is their turf.'),
#  ('c06926', "i'll tell you the effect!  it pisses me off!"),
#  ('c15144', 'what?'),
#  ('c19730', '\'intimate? !"'),
#  ('c12859', ') thought i needed a little change.  you like it?'),
#  ('c26148', 'then you still love me?'),
#  ('c20718',
#   "listen.  last night - oh christ, this'1l take forever to explain. god, michael..."),
#  ('c27231', 'lord chelmsford seems to want me to stay back with my basutos.'),
#  ('c17255', "do you think he'll take the job?"),
#  ('c00214', 'what happened to you?'),
#  ('c05319', 'you promised.'),
#  ('c11737', 'forgive you? i ought to knock you on your goddamn ass!'),
#  ('c00021',
#   'it\'s not "love me."  it\'s not "trust my handshake."  it\'s make the sale. get it signed.  there shouldn\'t be "confusion" about that.'),
#  ('c12494',
#   "no, walter!  i said i thought she kidnapped herself!  you're the one who's so fucking certain--"),
#  ('c16039', 'disease? what disease?'),
#  ('c15029', "the lazy fuck just didn't bother to look her up."),
#  ('c00990', "it's my nature."),
#  ('c01477', 'nerves.'),
#  ('c04480', "that is what i want. why don't you go and get your stuff?"),
#  ('c05494', "uh, you're driving a-"),
#  ('c10624',
#   "look, i've got a lot of problems and i'm trying to deal with them and the last thing i need is people spreading shit about me."),
#  ('c21828', '...and therafore there is no consequence?'),
#  ('c03450', 'oh, just traveling through, huh?'),
#  ('c10786',
#   "some people say you don't do much of anything when it comes to this case."),
#  ('c21661', "i've got a room at the institute i use when i stay late."),
#  ('c19871', "take 'er to the zoo -- retards like the zoo."),
#  ('c10964', 'yeah, right.'),
#  ('c23301', 'amateurs!'),
#  ('c22412', 'he did everything he could to take care of his heart?'),
#  ('c27193',
#   'hobby! what can she do? she cooks and she cleans. you gotta have a house to clean. you gotta have children to cook for. these are the terrible years for a woman, the terrible years.'),
#  ('c25518', 'what about jorgensen?'),
#  ('c15862',
#   "he's fine. but i'm afraid we don't get a chance to see each other very much these days."),
#  ('c15144', 'what do you do?'),
#  ('c07993', 'does that mean you love me?'),
#  ('c20060', 'flash, drop it--'),
#  ('c06603',
#   "you see the play? you've seen the play every performance?  but, don't you find it - i mean apart from everything else - don't you find it expensive?"),
#  ('c10416', 'they want to settle.    it means a lot of money.'),
#  ('c06621', 'yes, sir.'),
#  ('c06621', 'yes, sir. the rift effects all long-range communications.'),
#  ('c09160', "we're preparing a convoy for a delivery to peking."),
#  ('c15144', 'where ?'),
#  ('c05402', "you remember how a production eats up one's life."),
#  ('c20886',
#   "well, i mean it's not a total loss.  it is keeping a very capable thief off the street.."),
#  ('c13080', 'i guess so, sir.'),
#  ('c03489', "i know, but we're on a college campus..."),
#  ('c02060', 'i guess it was because i was a model prisoner.'),
#  ('c21228', '... would you like us to notify anyone for you?'),
#  ('c25408', 'oh my god!'),
#  ('c16541', "i bet.  going into people's homes."),
#  ('c12849', "and now that superman's out of the nice guy business..."),
#  ('c17053',
#   'i would have asked my sister, but its better to leave family out, always leads to trouble.'),
#  ('c13634', "yes.  that's true, you're getting a hell of a reputation."),
#  ('c15144', 'i am not!'),
#  ('c08461', 'tell me.'),
#  ('c12016', 'beth shalom? what are you talking about? who is this...?'),
#  ('c27022', 'like waking. like you always just woke up.\t\t\t\t\t\t\t *'),
#  ('c11931', "where's buckaroo?  is he alive?"),
#  ('c11719', 'you believe that?'),
#  ('c24162', 'who said that? gary cooper, james stewart, henry fonda? huh?'),
#  ('c20732', 'yeah. i bet he would.'),
#  ('c08774', 'claire...'),
#  ('c13221', "don't worry it's a non-dairy sauce made from soy milk."),
#  ('c13201', 'your excellency, something terrible has just happened.'),
#  ('c07544', "yes. i don't think you should leave them in the hall, do you?"),
#  ('c20202', "i'm sorry. let's go."),
#  ('c04488', '<u>shut up!  shut up and get on the floor</u>!'),
#  ('c25938', 'well sure, colonel --'),
#  ('c08620', 'the old lady?'),
#  ('c27193',
#   "lots of fires. they promote faster there. take a look at the last lt.'s list, half the guys on it came from that battalion. gotta think about your future, timmy. 115's the station."),
#  ('c23244', "yeah, it's pretty relevant considering my situation."),
#  ('c09805',
#   'our common heritage.  i am your only real friend, you know.  the only one who truly understands you.  i look forward to the day we meet again.  and i kill you.'),
#  ('c14166',
#   "i just don't get this all. it was them that went for me, brothers. you're not on their side and can't be. you can't be dim. it was someone we fillied with back in the old days... trying to get his own malenky bit of revenge after all this time. you remember, dim?"),
#  ('c19865', 'i know your parents.'),
#  ('c23583', "i'm going to florida."),
#  ('c14979', 'what are you going to do?'),
#  ('c15144', 'why not?'),
#  ('c11892', "how's the bottle?"),
#  ('c13446', 'go!'),
#  ('c13080', 'me, sir?'),
#  ('c00105', "don't ask any questions--just give it to me."),
#  ('c18238', "how'd you know that?  kay?"),
#  ('c10382', 'i have school.'),
#  ('c17779', "what's that supposed to mean?"),
#  ('c23520', 'if i were to spare a few policemen, where would i station them?'),
#  ('c15144', "he hasn't."),
#  ('c16202', 'would you remember his name?'),
#  ('c26538', "what's it mean?"),
#  ('c26004', 'unofficially, general greene.'),
#  ('c15144', "i'm here."),
#  ('c23519',
#   'would you like a little more champagne?  and maybe if we had some music -  - how do you dim these lights?'),
#  ('c18314', 'great.'),
#  ('c00214', 'what happened?'),
#  ('c14849',
#   "well, i didn't mean it, alan. why the fuck would i want to save a homeless shelter?"),
#  ('c23089', "i found it out a little late. i'm worth more dead than alive."),
#  ('c05629',
#   "she might!!! she might do it, albert, but you can't fuckin' tell me that she does!!!"),
#  ('c22230', 'do you bite your thumb at us? sir.'),
#  ('c23009', 'a mystery.'),
#  ('c22767',
#   "no, it's not that.  i ... can't drink from the bottle.  i ... gag."),
#  ('c05089', 'the ship....'),
#  ('c16377', 'i said i promise!'),
#  ('c12273', 'yes.'),
#  ('c21821', "probably. in my case it's probably a whole building."),
#  ('c25809', 'you got a gun?'),
#  ('c16070', 'well, shall we go through documentation?'),
#  ('c20664',
#   'why not? thai girls best in the world. thai food best in the world. thai dope best in the world.'),
#  ('c22117',
#   "no, they're away for the weekend. brad and i are watching the house."),
#  ('c04274', 'i know, i was wrong.  but morg, look, we got to get out.'),
#  ('c20338', 'ni!'),
#  ('c04323', 'did they give him special care?'),
#  ('c26701', "radar, he's underwater.  but he's definitely coming."),
#  ('c22062',
#   "i don't believe i've been so thrilled in my--oh, and that lincoln memorial! gee! there he is--mr. lincoln--looking right at you as you come up the steps-- sitting there like he was waiting for someone to come along--"),
#  ('c26487',
#   "i wish you'd listen to us. what about the meeting tomorrow? we need to frisk people."),
#  ('c18118',
#   "i polled my staff. the men say they'd hang around with him and the women say he's fuckable. and one of the men said he's fuckable."),
#  ('c00159', 'guess so.'),
#  ('c15144', '78th.'),
#  ('c17255', "don't worry.  we'll take it out of your share."),
#  ('c11719', "i - i...  i can't, michael.  there's stuff --- at the clinic -"),
#  ('c06192', "don't you dare."),
#  ('c11824', "which one's your building?"),
#  ('c09695', 'i hope everything is settled.'),
#  ('c18851', 'the university cannot do this. is the room safe?'),
#  ('c05089', 'i wonder where exactly is it he goes to work of evenings.'),
#  ('c25108', "didn't look like chicken to me, more like fried pussy cat."),
#  ('c02624', "i think he's moved..."),
#  ('c05494', 'uh-oh.'),
#  ('c00442', 'it was a good ad-lib, sir.'),
#  ('c11677', "let's go back, barry..."),
#  ('c09029',
#   "deputy director koessler doesn't want zero. all he cares about is low."),
#  ('c27257',
#   "here's my speech...  ...i know this shouldn't be acceptable to me, but it is. don't ask me why. i sense that your trouble is very big... and i'm scared for you... and so i'm doing what i think you need me to do. falling down in casinos is little stuff. it doesn't bother me. it has nothing to do with us."),
#  ('c18204', 'a friend?'),
#  ('c23244', 'yeah.'),
#  ('c27171', 'aha. poet or philosopher?'),
#  ('c24824', "nope. it's new stuff. no smell."),
#  ('c13602',
#   "okay. that nice lady. meets me in a bar. i'm saying what the fuck am i doing here anyway. she buys me a drink. she holds my hand. i'm looking at her saying i don't like you, bitch. but what the fuck. maybe i'll get to understand."),
#  ('c01162',
#   "shemp is right here in this room...two minutes from now, and at exactly 9:02pm, we'll catch up to him."),
#  ('c24511',
#   'you were such a super lady...  and then i... i been so lonely...'),
#  ('c00771', 'fourteen, harry.'),
#  ('c22847',
#   "how did you find him? it's such an out of the way apartment. can i fix you a drink?"),
#  ('c15457', 'oh, no. she brought me my meals.'),
#  ('c07447',
#   'those of us who call ourselves patriots are not seeking to give birth to an american nation, but to protect one that already exists.  it was born a hundred-and-seventy years ago at jamestown, virginia and has grown stronger and more mature with every generation reared and with every crop sown and harvested.  we are a nation and our rights as citizens of that nation are threatened by a tyrant three thousand miles away.'),
#  ('c15248',
#   "i am dubious, but i don't welsh. meet me at the stuck pig. seven o'clock. you're late, i walk. so help me, if i find out you cheated."),
#  ('c25712', "i think it's very sensible in the circumstances."),
#  ('c15370', "how 'bout you talk to 'em about me?  please do me that favor."),
#  ('c02145', 'fine.'),
#  ('c15144', 'how?'),
#  ('c10918',
#   "what seems important to these people is not determined by the amount of work it entails -- you're far from understanding the authorities if you believe that."),
#  ('c22334', "because of the future. i know what's going to happen."),
#  ('c14836', "i don't know. how do i know?"),
#  ('c12728', "i'm never going back."),
#  ('c15144', 'why would they exaggerate?'),
#  ('c18752', 'i feel like shit...'),
#  ('c16076', "now, you've got more sense than to put nosey onto this guy--!"),
#  ('c23875', 'norman...'),
#  ('c01513', "i can't take shorthand."),
#  ('c16870', 'not on my own beat, no.'),
#  ('c24463', 'say more.'),
#  ('c06301', "he can't fire me. lariviere already did that this morning."),
#  ('c06101', "i don't figure there's much i want money can't buy."),
#  ('c11645',
#   'i tried to save him! i was desperate to save him! he was the last best hope in the universe for real peace.'),
#  ('c15144', 'what about don?'),
#  ('c18831',
#   "try what other kids did.  keep each other awake.  we'll meet at debbie's tonight. at least if we don't sleep he can't get us."),
#  ('c03053', 'surely not.'),
#  ('c24210',
#   "whatever it is, it's out of your jurisdiction. this man is not a prisoner of war. not any more. he is a saboteur."),
#  ('c14921', 'i apologize.'),
#  ('c09954', "i don't know.  maybe."),
#  ('c19389',
#   "soran may still be obsessed with getting back. and if he is, he'll do anything to find that doorway again."),
#  ('c13390', 'how the hell did you get here.'),
#  ('c12110', "someone didn't want us to get to the party."),
#  ('c19312', "you've done pretty well."),
#  ('c19109', "gee, um...  i...i don't know what to say."),
#  ('c00468',
#   "ted, all my life i'd either been somebody's daughter or somebody's wife, or somebody else's mother. then all of a sudden, i was a thirty-two-year-old, highly neurotic woman who had just walked out on her husband and child.  i went to california because that was about as far away as i could get.  only... i guess it wasn't far enough. so i started going to a shrink.  ted, i've had time to think. i've been through some changes. i've learned a lot about myself."),
#  ('c05426',
#   'and your brother tom is a psychology professor and is married to...betsy --'),
#  ('c18256', 'the hoop-dee-doo!'),
#  ('c11997',
#   "they wanted to know if we'd had a chance to find out what happened to you the other night. they wanted to know if you remembered anything."),
#  ('c06893', 'irene is going to help.'),
#  ('c23618', 'what do you mean, odd? we was robbed like i told you.'),
#  ('c20703', 'there must be plenty of women who would be glad to go....'),
#  ('c22779', "i'll call the police."),
#  ('c23244', 'yeah?'),
#  ('c15265', "it's....whatever....that's not cool."),
#  ('c23009', "well how do <u>i</u> know what they're--"),
#  ('c13674', "most women wouldn't choose it."),
# ...
#  ('c15144', 'when?'),
#  ('c03036',
#   'by red, what rank would you say this black, officer, soldier is, colonel?'),
#  ('c03425',
#   'absolutely.  and how many times has letterman called the cops thinking that woman was down in his kitchen again?  it gets under your skin if you let it.'),
#  ('c06100', 'how high is that?'),
#  ('c25020', 'the federal building was too well guarded.'),
#  ('c09598',
#   "kill it! for go- what's wrong with you? don't you have a can of raid in the house?"),
#  ('c02055', "that's an order!"),
#  ('c23067',
#   "is that all you care about? that radio? can't you think of anything except yourself?"),
#  ('c11051', 'nice bunch of guys.'),
#  ('c19032',
#   'please, i beg of you.  the american army is there.  i am iraqi.  they will kill me.'),
#  ('c05452', 'i missed...'),
#  ('c06759', "but did you know i knew you'd know i'd know?"),
#  ('c09821', "c'mon, star.  climb on."),
#  ('c10582', "what's that, peanut?"),
#  ('c16784', "you left her.  how's that for a fact?"),
#  ('c14511', 'especially now.'),
#  ('c20324', 'you-you play... very well.'),
#  ('c18935', 'thanks.'),
#  ('c15144', "no, i wouldn't."),
#  ('c21297',
#   "it happens all the time.  i've got some warm milk all ready for you. why don't you jump into bed?  i'm gonna turn on your electric blanket, too. c'mon, now."),
#  ('c15144', 'do i?'),
#  ('c16183',
#   "it's your father. hank. your mother went to see him and he had a heart attack."),
#  ('c22166',
#   "ya know, i ain't never been in an institution of psychology before."),
#  ('c14848',
#   'is it really fab or are you just saying that to convince yourself?'),
#  ('c02155', "........... it's a bomb isn't it?"),
#  ('c24824', 'do you smell shit?'),
#  ('c18831', "you can't get him on the phone. he's out duckshooting now."),
#  ('c20879',
#   "well, isn't that nice? you just go right ahead and putter with your hands. that's all right. how do you do it?"),
#  ('c04875',
#   'why does everybody insult my intelligence, i have intelligence, intelligent people eat twinkies.'),
#  ('c21615',
#   "perhaps i'd better get you straightened out, mr. mitchell. you've been rather nice to me, in a couple of ways. and i'm grateful. but i don't think this entitles you to put me on a leash."),
#  ('c27225', 'donnie darko is a cool name. sounds like a superhero.'),
#  ('c18917', 'it was jane mckenna who sent you the dumper.'),
#  ('c27257', 'are you scared?'),
#  ('c16348', '...is everything okay?'),
#  ('c13829',
#   'by the time i\'m at the belt, you phone and say, "how are you?"  forty-five minutes later i reply, "not bad.  how are you?"'),
#  ('c23244', 'yeah, i crash there.'),
#  ('c15144', 'no.'),
#  ('c11855', 'do you want me to come up and tuck you in?'),
#  ('c07984', 'give him the sedative!'),
#  ('c08220',
#   "because i don't feel like sitting in a rubber room for forty-eight hours."),
#  ('c25221', 'of course!'),
#  ('c18629',
#   'hey, lady?  lady!  can you talk?  who are you?   this is not working.  think of something else.'),
#  ('c25408', 'oh god.'),
#  ('c15144', 'sleeeeew sheek baw...'),
#  ('c00142', 'i\'m only allowed "g" movies.'),
#  ('c03549', 'this is a ghost town.  nothing ever happens.'),
#  ('c02559',
#   "we better call the doctor... listen. i'll say how it happened, part i saw."),
#  ('c13551', 'gone where?'),
#  ('c26819', "kind of a bleak point of view there, isn't it marty?"),
#  ('c21469', 'one of your instincts?'),
#  ('c00993',
#   "i'm alice. mother said you'd be on your way. mrs. peel with you?"),
#  ('c06310', 'one hundred thousand. no... three hundred thousand.'),
#  ('c11719', 'i want to believe.'),
#  ('c18935', 'no thanks.'),
#  ('c02145', "i'm fine."),
#  ('c00978', 'an evil petting zoo?'),
#  ('c12320',
#   "he wants playmates.  oh he's a sweetheart, sal, you know i love him. but he's not going to be a good father. he's just not parenting material."),
#  ('c19928', 'tonight it is.'),
#  ('c06338', 'the family know?'),
#  ('c10666', 'really?'),
#  ('c00214', 'what happened?'),
#  ('c15144', 'so who was he with?'),
#  ('c10859', 'how do you know i will?'),
#  ('c24250',
#   "to know about it?  it was a kill squad. black on black. closed down two years ago. nobody wants to know about treadstone. not around here.  you better take this back to marty and make sure he knows what you're doing."),
#  ('c24808', 'how do you work it with the key?'),
#  ('c00306',
#   "this is incredible. i was just sitting here trying to figure out how to contact you. i mean, you don't have an answering service, right?"),
#  ('c27425', "you're frightened."),
#  ('c15297', 'everything in moderation, clerval.'),
#  ('c19521', 'is someone in the room with you?'),
#  ('c10351', 'no -- she asked me about cocaine.'),
#  ('c08052', 'nothing particular the matter with him, they tell me.  just -'),
#  ('c00373', "i can't guarantee that..."),
#  ('c22384', "you're american."),
#  ('c05734',
#   "right now, <i>your</i> presence is creating more of a threat.  i don't think you have any concept of what we do here--how meticulous our preparations must be.  we are about to send twelve people through 140 million miles of blackness to rendezvous with an object the size of a house and the color of coal.  so it's rather critical to point them in the right direction. and we certainly don't need you looking over our shoulders.  besides, i don't believe there is any evidence that the killer <i>is</i> amongst us.  i don't see too many other dead bodies littering the place."),
#  ('c15859',
#   'no one to back me up. now i have a good idea. so unless you come up with something better --'),
#  ('c08743', "and tell me that she's happy."),
#  ('c27432', 'i hear she was a terror to work with.'),
#  ('c08361', 'and no people.'),
#  ('c25648', "that's surprising.  he was leaving your office at the time..."),
#  ('c15433',
#   "yeah ... we're gonna paint in the spring. after the rains.  look good as new."),
#  ('c12728', 'and i said i would never leave you.'),
#  ('c12273', 'yes.'),
#  ('c19396', 'we have a daughter.'),
#  ('c20124', "you'll find enough cong up there."),
#  ('c07797',
#   "shit, skinny, we got railroad barons an' cattle barons, but you' re gonna be the first of the billiard barons."),
#  ('c18684', 'a very lucky thing indeed.'),
#  ('c06829',
#   'if i have given you any cause to be insulted, monsieur, may i offer you immediate satisfaction?'),
#  ('c20400', "you would never understand my life. you're not chinese."),
#  ('c19181', "i don't take my orders from you; not anymore."),
#  ('c20332',
#   "right.  so you're saying it survived a high speed impact with water without a scratch?"),
#  ('c15246', "you're kind of cultivating a new look."),
#  ('c27257',
#   "well, i'll ask him, but i don't think he'll be very keen. he's already got one, you see?"),
#  ('c10382',
#   'school, school.  regular.  i used to get pretty good grades in school, you know.'),
#  ('c08020', "we sell children's toys --"),
#  ('c26138',
#   "all i know is carmen's going to be a citizen, and i don't think it'll work out for us if i'm not."),
#  ('c02145', 'he was fine when he left here, and now look at him.'),
#  ('c10435', "no. but it's a nice idea."),
#  ('c03300',
#   'an aircraft engineer down the peninsula designed it. he worked it out in his spare time.'),
#  ('c15649', 'voice stress analyzer.'),
#  ('c18849',
#   'what do you want me to do, just step out in the alley? is that it?'),
#  ('c02199', 'some say you are, rocky.'),
#  ('c08282', "okay, now you're making this personal, and it isn't --"),
#  ('c08465',
#   "i'm afraid our furry companion has gone and done something rather rash."),
#  ('c04590', 'oh, sure.  here, this can be mommy.'),
#  ('c15144', 'who to?'),
#  ('c25513',
#   "of course. and you tell your father for me -- we may be on opposite sides of the fence, but i'm always glad to hear of a man who holds to his own opinions. as long as people do that -- the country's all right. do you understand, martin?"),
#  ('c15144', 'where?!'),
#  ('c13080',
#   'you try to frighten me, sir, admit so, sir. this is some new form of torture. say it, brother, sir.'),
#  ('c07797',
#   "so they'll put her back in! it's not like it's gonna matter if she breaks something!"),
#  ('c23696', 'you sound like a man with a couple of kids.'),
#  ('c08911', 'what if someone tries to steal it?'),
#  ('c11211', 'dad, they come in through the doors.'),
#  ('c13551', "we're gone."),
#  ('c11677',
#   "the trick is to look like you don't need it, then they give you shit for free."),
#  ('c10494',
#   "i've been trying to talk to him about it.  he says everything's fine, but i don't know. automatically, you know, i leap to the worst conclusions."),
#  ('c12273', 'yes.'),
#  ('c22271',
#   "you can keep your will!  i ain't forgettin' you was all set to shoot her yourself...what kind o' man are you, anyway."),
#  ('c05108',
#   'i see. so playing hockey and attending wakes-these practices are standard operating procedure.'),
#  ('c13942', 'how do you know?  did you take his temperature?'),
#  ('c15144', 'do you have the...'),
#  ('c26971', 'i think so.'),
#  ('c13719', 'passport?'),
#  ('c01334', 'the sets were good.'),
#  ('c22522', "i don't know they just always need it."),
#  ('c14721', 'if i told you it might not come true.'),
#  ('c22953', "if there's anything i can do for you -"),
#  ('c17428',
#   "don't get near 'em.  the plants! they're alive.  those things can imitate anything..."),
#  ('c22779', "um, okay. i'll call my study partner."),
#  ('c26673',
#   "it isn't him.  frank, you brought me in on this in the beginning because you wanted my opinion if he was capable of doing this."),
#  ('c09403', 'i always do.'),
#  ('c10268',
#   "i wish that was all miss weathers, but there's more. the killer left a note."),
#  ('c00994', 'i believe i should interview the widow alone.'),
#  ('c16317', 'copy. and lundegaard too.'),
#  ('c15413', "don't you want to go to the airport?"),
#  ('c24426', 'you want to go talk?'),
#  ('c13862', 'you can trust me on this one.'),
#  ('c15144', 'what?...'),
#  ('c06450',
#   "well make a dog, make a parakeet! i'm sure you'll think of something."),
#  ('c12268', "a man just died, you're hitting on me with science."),
#  ('c05808', "but dick laurent is dead, isn't he?"),
#  ('c14398', 'where did you send the message to peter kurten?'),
#  ('c24210',
#   "is the war worth it?  is it worth a one-term presidency?  because i think right now that's what we're looking at."),
#  ('c15144', 'then you do it.'),
#  ('c03983', 'well. yeah. you may not want to.'),
#  ('c09201', "my shift ends at four, but i couldn't --"),
#  ('c01119',
#   "me?  i'm busy.  just finished one script.  i'm due on another assignment."),
#  ('c02331', "let's go see them."),
#  ('c27452', 'ready.'),
#  ('c05160', "i'd better get back now."),
#  ('c13293',
#   'it will be done. but what of the american expedition? they leave tomorrow as well.'),
#  ('c15144', 'why?'),
#  ('c08527', "exactly.  don't you wonder where i'm really hiding simone?"),
#  ('c06777', 'no chance.'),
#  ('c04051', 'and maybe you lie...'),
#  ('c12940',
#   'they fear change.  the new caesar must be honest enough to know when the emperorship is no longer feasible.  you could be the one, the emperor, the man who oversees the rebirth of the republic.'),
#  ('c09877',
#   "it's the only answer. everything has a use and if we let it be used for its purpose, we could solve all our problems. food was meant to be eaten, not stored away in restaurants while poor people starved; clothing was meant to be worn, not piled up in stores while people went naked. doesn't that make sense?"),
#  ('c25413', "a good place for what?  he's insane!"),
#  ('c25664', 'he may be.'),
#  ('c14991', 'still, it must be kinda rough.'),
#  ('c13293',
#   "i done it all. i've done an' seen everything'. believe what i'm tellin' ya -- ya shoulda seen the night in brooklyn, i smacked 'ginny' russo outta the ring, september 14, 1923 -- same night firpo knocked dempsey outta the ring. but who got the press? he did. he had a manager -- september 14, 1923."),
#  ('c00094', "why don't we both forget about him?"),
#  ('c15144', 'and you have him?'),
#  ('c15144', "he's a plumber."),
#  ('c18543', 'i thought you said they needed discipline?'),
#  ('c07286',
#   'my old lady, every word outta her mouth, when you gonna get married?'),
#  ('c18755', "why don't you just stick your finger in and stir it up."),
#  ('c12273', 'yes.'),
#  ('c26208',
#   "well, that's good. it's about time to eat and you know what i'm cravin'? some of that take out chicken. why don't you run get some of it, honey, for lunch?"),
#  ('c15144', 'but how can i do that?'),
#  ('c16332', 'how much would i get paid?'),
#  ('c05340',
#   'may i introduce my father? he is on a short visit here and returning very soon to salzburg. he would so much like to kiss your hand. it would make his whole stay so memorable for him.'),
#  ('c19521', "why don't we go to your room-"),
#  ('c15144', 'then what?'),
#  ('c23152', 'and what does that make you?'),
#  ('c22976', 'tell me what she wore.'),
#  ('c22144',
#   "it sounds to me like everybody's just a little jumpy. and since all it is is a drop, the welshman's got nothing at stake. i say we go to his 'troughed off' bar. it'll calm his nerves, we drop the bag, and we all get back to our lives."),
#  ('c07019', 'thank you, leon... thank you, masses.  can i make a speech now?'),
#  ('c20286',
#   "but, i don't know. i'm just scared that things would change. between us."),
#  ('c25003', "i don't want you talking to our customers like that again."),
#  ('c26410', "how do i know you'll keep your word?"),
#  ('c20881', "aldys, don't miss your prom--it only happens once."),
#  ('c02076', 'hold on. stop. take a deep breath. tell me what happened.'),
#  ('c23095',
#   "there'll be three, four men at the most.  i have some backup, nothing will happen."),
#  ('c20710', 'ah!'),
#  ('c13631', "you sure it wasn't me?"),
#  ('c15144', "that's it."),
#  ('c02060',
#   'no.  i cannot take orders from that underwear model.  that wingnut washed out of nasa for sneaking two victoria secret wannabes into a flight simulator.'),
#  ('c08771', 'for a <u>dead</u> <u>dog</u>?'),
#  ('c27272', "can you help? i've no money..."),
#  ('c06624',
#   "look it, mister... you wanna have your way, you take it. i'll do whatever you want. but you gotta let me go. you can't do this! you can't keep me here!"),
#  ('c21377', "if you're trying to cheer me up you're doing a helluva job --"),
#  ('c26538', 'what do you mean?'),
#  ('c15628',
#   'the american assured the colonel that they would watch everything.'),
#  ('c12575', '...why are we here in the <u>first</u> place...?'),
#  ('c15504', 'i love you, my brother, do you know that?'),
#  ('c08060',
#   "and there's this brilliant conductor in purple briefs with no bangs cursing his ass off in finnish."),
#  ('c04398', 'you wanna have a drink before we start dancing?'),
#  ('c19900', "we've no proof, of course, but we rather think so, yes."),
#  ('c05440', 'i said "yes."'),
#  ('c10268', "hauser?  you're hauser."),
#  ('c10952', "joe, i can't look at you any more."),
#  ('c20310', "this here's loretta."),
#  ('c09029', 'three-one-zero, aye!'),
#  ('c11051', 'oh, an tv a minute and already an attitude.'),
#  ('c14149', 'yes, it is, hal.'),
#  ('c20964', "i'm here, i'm listening."),
#  ('c10387', 'i was right. you are superman.'),
#  ('c13397',
#   'okay, pal...  i accept the compliment, but go easy -- my knees start a-knocking when you turn on the charm full blast.'),
#  ('c03243', 'sir.  i thought those records were sealed.'),
#  ('c02206', "no. i'll wait here."),
#  ('c24077', "after that my parents never let me go to dignan's again."),
#  ('c04117', 'finish him, finish him. your way.'),
#  ('c12273', "yes, but i wouldn't..."),
#  ('c20736', "i'm serious, frances. this is important."),
#  ('c12488', 'god.  this is the kitchen, huh?'),
#  ('c25924', "just tell me who did it and i'll go get him, baby."),
#  ('c18307', "how do you know there's two ounces in a drink?"),
#  ('c17957', 'about forty minutes.'),
#  ('c15144', 'no.'),
#  ('c14021', "i'll get it.  please, i don't mind."),
#  ('c10080', 'realized what?'),
#  ('c10527',
#   "well, i haven't seen any. i wouldn't worry about it. look, i better go."),
#  ('c13220', 'now what kind of statue was that?'),
#  ('c14486', "deserters would have run, they wouldn't have engaged."),
#  ('c07754', "which we've overflown twice."),
#  ...]
